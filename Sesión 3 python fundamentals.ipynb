# %%
tupla = (11, "Pizza", False, "H20.ai", 39.4560)

print (tupla)

lista = []

lista.append(tupla[0])
lista.append(tupla[1])
lista.append(tupla[2])
lista.append(tupla[3])
lista.append(tupla[4])

print (lista)

diccionario = {}

diccionario[1]=lista[0]
diccionario[2]=lista[1]
diccionario[3]=lista[2]
diccionario[4]=lista[3]
diccionario[5]=lista[4]

diccionario
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(11, &#39;Pizza&#39;, False, &#39;H20.ai&#39;, 39.456)
# [11, &#39;Pizza&#39;, False, &#39;H20.ai&#39;, 39.456]
# Out[11]: {1: 11, 2: &#39;Pizza&#39;, 3: False, 4: &#39;H20.ai&#39;, 5: 39.456}</div>
